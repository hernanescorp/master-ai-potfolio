# %% [markdown]
# # **JUPYTER LAB & NOTEBOOKS**

# %% [markdown]
# ## Jupyter iPythin Commands

# %%
# %pwd
# %ls
# Out:
#  El volumen de la unidad C es Local Disk
#  El n�mero de serie del volumen es: B43B-1DB6
#
#  Directorio de c:\Users\herna\OneDrive\Escritorio\New_ERA\masterIA\master-ai-potfolio\notebooks\03_programming_for_ai\theory
#
# 10/05/2026  13:59    <DIR>          .
# 03/05/2026  01:39    <DIR>          ..
# 03/05/2026  01:38                 0 .gitkeep
# 10/05/2026  14:14             6.126 1a_JupyterLab_and_notebooks.ipynb
#                2 archivos          6.126 bytes
#                2 dirs  17.046.376.448 bytes libres

# %%
# %reset
# Out:
# Nothing done.

# %%
a = 10
print(a)

# %xdel a
print(a)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       1 a = 10
#       2 print(a)
#       3
#       4 get_ipython().run_line_magic('xdel', 'a')
# ----> 5 print(a)
#
# NameError: name 'a' is not defined

# %%
# %run 1a_JupyterLab_and_notebooks.ipynb
# Out:
#  El volumen de la unidad C es Local Disk
#  El n�mero de serie del volumen es: B43B-1DB6
#
#  Directorio de c:\Users\herna\OneDrive\Escritorio\New_ERA\masterIA\master-ai-potfolio\notebooks\03_programming_for_ai\theory
#
# 10/05/2026  13:59    <DIR>          .
# 03/05/2026  01:39    <DIR>          ..
# 03/05/2026  01:38                 0 .gitkeep
# 10/05/2026  14:14             6.126 1a_JupyterLab_and_notebooks.ipynb
#                2 archivos          6.126 bytes
#                2 dirs  17.111.166.976 bytes libres
# Nothing done.
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       1 a = 10
#       2 print(a)
#       3
#       4 get_ipython().run_line_magic('xdel', 'a')
# ----> 5 print(a)
#
# NameError: name 'a' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 with databricks_notebook_exec_env(r'c:\Users\herna\OneDrive\Escritorio\New_ERA\masterIA\master-ai-potfolio', r'1a_JupyterLab_and_notebooks.ipynb') as file:
# ----> 2         get_ipython().run_line_magic('run', '-i {file}')
#
# Cell In[21], line 5
#       1 a = 10
#       2 print(a)
#       3
#       4 get_ipython().run_line_magic('xdel', 'a')
# ----> 5 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# Ejecuta varias veces y muestra la media y el std

# %%
# %timeit sum(range(1000))
# Out:
# 24.7 μs ± 2.31 μs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# Da informacion detallada

# %%
# %prun sum(range(1000))
# Out:
#          4 function calls in 0.001 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)

# %% [markdown]
# Show the names of the variables defined in the runtime enviroment.

# %%
a = 1
b = "string"

# %who 
# %who int
# %who str

# %whos
# %who_ls
# Out:
# a	 b	 file
# a
# b	 file
# Variable   Type    Data/Info
# ----------------------------
# a          int     1
# b          str     string
# file       str     1a_JupyterLab_and_notebooks.ipynb
# ['a', 'b', 'file']

# %%
# %history
# Out:
# print(1)
# ?keyword
# ?np.linspace
# !ls
# !ls
# !pwd
# !pwd
# %pwd
# %pwd
# %ls
# %pwd
# %ls
# %reset
# a = 10
# print(a)
#
# %xdel a
# a = 10
# print(a)
#
# %xdel a
# print(a)
# %run 1a_JupyterLab_and_notebooks.ipynb
# %run 1a_JupyterLab_and_notebooks.ipynb
# %run 1a_JupyterLab_and_notebooks.ipynb
# %run 1a_JupyterLab_and_notebooks.ipynb
# %pwd
# %ls
# %pwd
# %ls
# %reset
# a = 10
# print(a)
#
# %xdel a
# print(a)
# %run 1a_JupyterLab_and_notebooks.ipynb
# %timeit sum(range(1000))
# %prun sum(range(1000))
# %who
# a = 1
# b = "string"
# %who
# a = 1
# b = "string"
# %who
# %who int
# a = 1
# b = "string"
# %who
# %who int
# %who str
# a = 1
# b = "string"
# %who
# %who int
# %who str
# %whos
# a = 1
# b = "string"
# %who
# %who int
# %who str
# %whos
# a = 1
# b = "string"
# %who
# %who int
# %who str
# %whos
# a = 1
# b = "string"
# %who
# %who int
# %who str
# %whos
# %who_ls
# a = 1
# b = "string"
#
# %who
# %who int
# %who str
#
# %whos
# %who_ls
# %history
# %history -n 5
# %history
