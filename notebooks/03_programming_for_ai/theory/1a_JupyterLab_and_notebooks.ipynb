# %% [markdown]
# # **JUPYTER LAB & NOTEBOOKS**

# %%
from databricks.sdk.runtime import *

# %% [markdown]
# Kind of digital version of a scientist physical notebook.
# - notes
# - charts
# - formulas
# - data
#
# ## JupyterLab, Notebooks and Kernels
# - JupyterLab: The interface where we manage Files, open terminals, run code and visualize results.
# - Notebook:Each document that represents a notebook.
# - Kernel: The engine that actually does the calculations in the background
#
# ## Cells
# A content unit that can be edited and rendered or executed.

# %%
import sys

print(sys.version)
print(sys.executable)

# %% [markdown]
# ## Multimedia and rich Output

# %%
import numpy  as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Jupyter iPythin Commands

# %% [markdown]
# Help:

# %%
# %pdoc np.linspace

# %% [markdown]
# Shell commands are interpreted by prefixing them with: **!**

# %%
# !ls

# %%
# !pwd

# %%
# %pwd
#%ls

# %%
# %reset

# %%
a = 10
print(a)

# %xdel a
print(a)

# %%
# El comando %run ejecuta otro notebook en el entorno actual.
# %run 1a_JupyterLab_and_notebooks.ipynb

# %% [markdown]
# Ejecuta varias veces y muestra la media y el std

# %%
# %timeit sum(range(1000))

# %% [markdown]
# Da informacion detallada

# %%
# %prun sum(range(1000))

# %% [markdown]
# Show the names of the variables defined in the runtime enviroment.

# %%
c = 2

# %%
a = 1
b = "string"

# %who #Shows all variables
# %who int #Shows all int variables
# %who str #Shows all str variables

# %whos #shows all variables with type
# %who_ls #returns a list of variables

# %%
# %history

# %%
from pyspark.dbutils import DBUtils

dbutils = DBUtils(spark)
dbutils.library.restartPython()

# %%
# %history
